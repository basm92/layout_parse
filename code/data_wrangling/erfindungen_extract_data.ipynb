# %% [markdown]
# # `erfindungen_extract_data.ipynb`
#
# This file extracts the data from the "Erfindungen" overview of patents until 1852 in the Austro-Hungarian empire. The .pdf already contains implicit text data, however, OpenAI Chat Completions cannot handle this very well. Hence, we opted to extract the text manually using the `tabula` piece of software.
#
# See [here](https://tabula.technology/) how to install tabula. It's a rule based approach based on either row finding or column finding. The base file that I use has column finding. This is a real nice basic DataFrame, but it omits the last observations on the page (it misses it).
#
# Hence, I augment it with
#
# The program `geeqie`
#
# ```
# sudo apt-get install geeqie
# ```
# helps to find the precise coordinates. See [here](https://askubuntu.com/questions/298877/which-image-viewer-is-able-to-show-coordinates) (View > Pixel Info).

# %% [markdown]
# ## Clean Data
#
# - First, we clean the basic dataset of Column Headers and sort the data.
# - Then, we find out which numbers are missing from the list (set difference). We also manually append the last number in the document, 5833.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

data = (pd.read_csv("../../data/patent_data/interim_patent_data/tabula-erfindungsprivilegien_without_first_page_basic.csv").
    iloc[:, 1:13])

data = data[data['PrivRegNr'] != "PrivRegNr"]
data['PrivRegNr'] = pd.to_numeric(data['PrivRegNr'])
data.sort_values('PrivRegNr', inplace=True)

# %%
present_elements = set(data['PrivRegNr'])
all_elements = set([i for i in range(1, 5816)] + [5833])

missing_elements = all_elements.difference(present_elements)

# %% [markdown]
# # Appending the dataset with the missing elements
#
# Write a function that takes `missing_elements` as input, then parses each `.csv`, merges the rows from the missing number and the row below per column, and then coalesce the 2 columns next to "Schlagworte" if one of those columns is empty. Then extracts the rows (including column names) for the `missing_elements`.

# %%
def list_files_in_directory(path):
    # List all files in the directory
    return [str(file) for file in Path(path).iterdir() if file.is_file()]
def coalesce_columns(df, col1, col2):
    """
    Merge two columns into one by filling missing values from col1 with values from col2.
    """
    return df[col1].combine_first(df[col2])

def merge_missing_rows(df):
    """
    Merge rows where the 'PrivRegNr' is missing.
    """
    merged_row = df.iloc[0].combine_first(df.iloc[1])
     # Create a new DataFrame with the merged row
    merged_df = pd.DataFrame([merged_row])  # Wrap the Series in a list to create a DataFrame

    return merged_df

def is_column_empty(df, column_idx):
    """
    Check if a column is completely empty (contains no text or all values are NaN).
    """
    # Step 1: Replace empty strings with NaN
    df.iloc[:, column_idx].replace("", np.nan, inplace=True)
    
    # Step 2: Check if all values in the column are NaN
    return df.iloc[:, column_idx].isna().all()

def process_csv(file_path, missing_elements):
    """
    Main function to process the CSV, merge rows with missing elements,
    coalesce Schlagworte columns, and extract rows with missing elements.
    """
    
    out = pd.DataFrame()
    files = list_files_in_directory(file_path)
    for file in files:
        print(file)
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file).reset_index()
        df['PrivRegNr'] = pd.to_numeric(df['PrivRegNr'])
        
        # Filter the observations on the missing elements and the row below
        retain = df[df['PrivRegNr'].isin(missing_elements)]
        
        if not retain.empty:
            first_int_index = retain.index[0]  # Get the first index directly
            second_int_index = first_int_index + 1
            keep = [first_int_index, second_int_index]
            
            try:
                # Always use `df.loc[[index]]` to ensure a DataFrame is returned
                df = df.loc[keep]
            except:
                # Wrap `first_int_index` in a list to ensure it remains a DataFrame
                df = df.loc[[first_int_index]]
        else:
            # Handle case where `retain` is empty
            pass

        # Merge the rows of the retained df
        if df.shape[0] > 1:
            df = merge_missing_rows(df)
            
        # Coalesce columns next to 'Schlagworte' if one of these is empty:
        if "Schlagworte" in df.columns:
            col_idx = df.columns.get_loc("Schlagworte")
        else:
            col_idx = np.where(data.columns.str.contains('Schlag'))[0][0]
        if (is_column_empty(df, col_idx+1) | is_column_empty(df, col_idx+2)):
            df['Ort'] = coalesce_columns(df, df.columns[col_idx+1], df.columns[col_idx+2])
        
        # Append the new line to the already existing df
        out = pd.concat([out, df], ignore_index=True)

    return out

# %%
#data.loc[[1,2]]
missing_obs = process_csv("../../data/patent_data/interim_patent_data/augment", missing_elements)
print(missing_obs.shape)
print(len(missing_elements))
#data[data.columns.str.contains("Schlagworte", case=False)]
# Out:
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-62.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-99.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-143.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-178.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-148.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-106.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-27.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Unnamed: 3', 'Name2',
#        'Vorname2', 'Unnamed: 6', 'Name3', 'Vorname3', 'Titel Schlagworte',
#        'Unnamed: 10', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-46.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-90.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Unnamed: 4',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel Schlagworte', 'Unnamed: 9',
#        'Unnamed: 10', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-24.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-132.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-49.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-134.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-176.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-163.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-185.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-109.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-101.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-199.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-111.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-34.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-123.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-138.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-1.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-4.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-140.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Unnamed: 9', 'Schlagworte',
#        'Unnamed: 11', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-186.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-168.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-42.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-91.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-67.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-51.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-61.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-112.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-25.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-219.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-130.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-225.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-189.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-57.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-32.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-22.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-31.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-66.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-115.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-75.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-14.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-153.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-226.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-53.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-48.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-107.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-159.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-181.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-100.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-71.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-50.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Unnamed: 7', 'Titel', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-77.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-9.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-16.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-120.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-129.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Unnamed: 3', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Unnamed: 8', 'Titel', 'Schlagworte',
#        'Unnamed: 11', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-156.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-192.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-60.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-198.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-117.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-202.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-213.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-23.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-85.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-37.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-157.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-183.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-167.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2',
#        'Unnamed: 5', 'Name3', 'Vorname3', 'Unnamed: 8', 'Titel', 'Schlagworte',
#        'Unnamed: 11', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-7.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-203.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-218.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Unnamed: 4',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-116.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-124.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-169.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-147.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-128.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Ort', 'Unnamed: 10',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-188.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-103.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-65.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-194.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-221.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-171.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-136.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-184.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-222.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Unnamed: 4',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-122.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-133.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-96.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-180.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-165.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Unnamed: 6', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-200.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-83.csv
# Index(['index', 'PrivRegNr', 'Unnamed: 1', 'Name1', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Unnamed: 9', 'Schlagworte',
#        'Unnamed: 11', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-205.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Unnamed: 5', 'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-17.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-2.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-73.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-102.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-36.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-127.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-135.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-173.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-191.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Unnamed: 4',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Unnamed: 9', 'Schlagworte',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-64.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-52.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-21.csv
# Index(['index', 'PrivRegNr', 'Unnamed: 1', 'Name1', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-70.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-82.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Unnamed: 3', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-18.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-30.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Unnamed: 4',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-182.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-54.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-214.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-174.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-204.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-68.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-12.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-152.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-0.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-212.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-151.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Unnamed: 6', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-146.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-28.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-11.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-161.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-92.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-131.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-197.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-104.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-162.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-175.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-79.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-55.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-88.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-209.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-72.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-74.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-172.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-19.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Unnamed: 3', 'Name2',
#        'Vorname2', 'Unnamed: 6', 'Name3', 'Vorname3', 'Unnamed: 9', 'Titel',
#        'Unnamed: 11', 'Schlagworte', 'Unnamed: 13', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-137.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-108.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-8.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-63.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-89.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-94.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-80.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-58.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-44.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-110.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-149.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
# ...
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-20.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-206.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Unnamed: 3', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-26.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-160.csv
# Index(['index', 'PrivRegNr', 'Unnamed: 1', 'Name1', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-210.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-76.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-84.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-45.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-215.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Unnamed: 7', 'Titel', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-125.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-86.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-97.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-139.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-155.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-41.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-158.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-196.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-211.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-145.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-3.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-81.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Unnamed: 3', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-208.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-164.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-113.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-105.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-98.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-224.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-144.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Unnamed: 2', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-121.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-56.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-141.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-33.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Ort', 'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-35.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-13.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-15.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-39.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-187.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-6.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-190.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-217.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-216.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-118.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-166.csv
# Index(['index', 'PrivRegNr', 'Unnamed: 1', 'Name1', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Unnamed: 9', 'Schlagworte',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-38.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel Schlagworte', 'Unnamed: 8', 'Unnamed: 9', 'Ort',
#        'Jahr', 'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-150.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-119.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Unnamed: 8', 'Schlagworte', 'Unnamed: 10', 'Ort',
#        'Jahr', 'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-47.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-220.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-170.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-126.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatum'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-40.csv
# Index(['index', 'PrivRegNr', 'Name1', 'Vorname1', 'Name2', 'Vorname2', 'Name3',
#        'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 9', 'Ort', 'Jahr',
#        'Einreichdatu'],
#       dtype='object')
# ../../data/patent_data/interim_patent_data/augment/tabula-erfindungsprivilegien_without_first_page-87.csv
# Index(['index', 'PrivRegNr', 'Unnamed: 1', 'Name1', 'Vorname1', 'Name2',
#        'Vorname2', 'Name3', 'Vorname3', 'Titel', 'Schlagworte', 'Unnamed: 10',
#        'Ort', 'Jahr', 'Einreichdatum'],
#       dtype='object')
# (227, 27)
# 270

# %% [markdown]
# ## Extract using `fitz`
#
# Manually extract the already OCR'ed text using `fitz` library.

# %%
import fitz  # PyMuPDF

def extract_text(pdf_file, export_file_name, x1, x2, y1, y2):
    
    doc = fitz.open(pdf_file)
    extracted_text = ""
    # Iterate over all the pages in the PDF
    for page_num in range(doc.page_count):
        page = doc.load_page(page_num)  # Load each page
        # Define the cropping rectangle: (x1, y1, x2, y2)
        crop_rect = fitz.Rect(x1, y1, x2, y2)
        # Crop the page
        page.set_cropbox(crop_rect)
        # Extract the text from the cropped area
        cropped_text = page.get_text("text")  # Extract text after cropping
        # Append the text from each page
        extracted_text += cropped_text 

    # Optionally, save the extracted text to a file
    with open(f"{export_file_name}.txt", "w") as f:
        f.write(extracted_text)
        
    return(extracted_text)

# %%
x1 = 682 # Left boundary of the cropping rectangle
x2 = 725  # Right boundary of the cropping rectangle
y1 = 62
y2 = 540
# Load the PDF file
pdf_file = '../../data/patent_data/raw_patent_data/erfindungsprivilegien_without_first_page.pdf'


places = extract_text(pdf_file, "place_names", x1=x1, x2=x2, y1=y1, y2=y2)

# %%
x1 = 723
x2 = 749

year = extract_text(pdf_file, "year", x1=x1, x2=x2, y1=y1, y2=y2)
