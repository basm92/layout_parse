# %% [markdown]
# ## Querying the GPT API to Transcribe the "Erfindungen" from 1816 to 1852
#
# These serve as important pre-trend indicators. Each observation represent an Austrian patent. The raw data is already in table format, so GPT should do an easy job transcribing this to actual csv's. In the box below, I put the prompt that I want to use.

# %%
import pandas as pd
import numpy as np
import base64
import requests
from pdf2image import convert_from_path
import os
from io import StringIO


from dotenv import load_dotenv
import os

import openai

# Load environment variables from .env file
load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')

# Specifiy the prompt
prompt = """
Transcribe the table in the attached picture in a .csv format. Use the "\t" as the delimiter. Output ONLY the parsed data, no text. Use the same headers as in the table. There are 12 headers. The table is in German. 
"""

# %% [markdown]
# ## Convert Images to .jpg
#
# And set up GPT parameters.

# %%
def pdf_to_jpg(pdf_path, output_folder):
    # Convert PDF to a list of images
    images = convert_from_path(pdf_path)
    
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Save each image as a JPG file
    for i, image in enumerate(images):
        image_path = os.path.join(output_folder, f'page_{i + 1}.jpg')
        image.save(image_path, 'JPEG')
        print(f'Saved {image_path}')

# Example usage
pdf_path = '../../data/patent_data/raw_patent_data/erfindungsprivilegien_without_first_page.pdf'
output_folder = '../../data/patent_data/interim_patent_data'
pdf_to_jpg(pdf_path, output_folder)
# Out:
# Saved ../../data/patent_data/interim_patent_data/page_1.jpg
# Saved ../../data/patent_data/interim_patent_data/page_2.jpg
# Saved ../../data/patent_data/interim_patent_data/page_3.jpg
# Saved ../../data/patent_data/interim_patent_data/page_4.jpg
# Saved ../../data/patent_data/interim_patent_data/page_5.jpg
# Saved ../../data/patent_data/interim_patent_data/page_6.jpg
# Saved ../../data/patent_data/interim_patent_data/page_7.jpg
# Saved ../../data/patent_data/interim_patent_data/page_8.jpg
# Saved ../../data/patent_data/interim_patent_data/page_9.jpg
# Saved ../../data/patent_data/interim_patent_data/page_10.jpg
# Saved ../../data/patent_data/interim_patent_data/page_11.jpg
# Saved ../../data/patent_data/interim_patent_data/page_12.jpg
# Saved ../../data/patent_data/interim_patent_data/page_13.jpg
# Saved ../../data/patent_data/interim_patent_data/page_14.jpg
# Saved ../../data/patent_data/interim_patent_data/page_15.jpg
# Saved ../../data/patent_data/interim_patent_data/page_16.jpg
# Saved ../../data/patent_data/interim_patent_data/page_17.jpg
# Saved ../../data/patent_data/interim_patent_data/page_18.jpg
# Saved ../../data/patent_data/interim_patent_data/page_19.jpg
# Saved ../../data/patent_data/interim_patent_data/page_20.jpg
# Saved ../../data/patent_data/interim_patent_data/page_21.jpg
# Saved ../../data/patent_data/interim_patent_data/page_22.jpg
# Saved ../../data/patent_data/interim_patent_data/page_23.jpg
# Saved ../../data/patent_data/interim_patent_data/page_24.jpg
# Saved ../../data/patent_data/interim_patent_data/page_25.jpg
# Saved ../../data/patent_data/interim_patent_data/page_26.jpg
# Saved ../../data/patent_data/interim_patent_data/page_27.jpg
# Saved ../../data/patent_data/interim_patent_data/page_28.jpg
# Saved ../../data/patent_data/interim_patent_data/page_29.jpg
# Saved ../../data/patent_data/interim_patent_data/page_30.jpg
# Saved ../../data/patent_data/interim_patent_data/page_184.jpg
# Saved ../../data/patent_data/interim_patent_data/page_185.jpg
# Saved ../../data/patent_data/interim_patent_data/page_186.jpg
# Saved ../../data/patent_data/interim_patent_data/page_187.jpg
# Saved ../../data/patent_data/interim_patent_data/page_188.jpg
# Saved ../../data/patent_data/interim_patent_data/page_189.jpg
# Saved ../../data/patent_data/interim_patent_data/page_190.jpg
# Saved ../../data/patent_data/interim_patent_data/page_191.jpg
# Saved ../../data/patent_data/interim_patent_data/page_192.jpg
# Saved ../../data/patent_data/interim_patent_data/page_193.jpg
# Saved ../../data/patent_data/interim_patent_data/page_194.jpg
# Saved ../../data/patent_data/interim_patent_data/page_195.jpg
# Saved ../../data/patent_data/interim_patent_data/page_196.jpg
# Saved ../../data/patent_data/interim_patent_data/page_197.jpg
# Saved ../../data/patent_data/interim_patent_data/page_198.jpg
# Saved ../../data/patent_data/interim_patent_data/page_199.jpg
# Saved ../../data/patent_data/interim_patent_data/page_200.jpg
# Saved ../../data/patent_data/interim_patent_data/page_201.jpg
# Saved ../../data/patent_data/interim_patent_data/page_202.jpg
# Saved ../../data/patent_data/interim_patent_data/page_203.jpg
# Saved ../../data/patent_data/interim_patent_data/page_204.jpg
# Saved ../../data/patent_data/interim_patent_data/page_205.jpg
# Saved ../../data/patent_data/interim_patent_data/page_206.jpg
# Saved ../../data/patent_data/interim_patent_data/page_207.jpg
# Saved ../../data/patent_data/interim_patent_data/page_208.jpg
# Saved ../../data/patent_data/interim_patent_data/page_209.jpg
# Saved ../../data/patent_data/interim_patent_data/page_210.jpg
# Saved ../../data/patent_data/interim_patent_data/page_211.jpg
# Saved ../../data/patent_data/interim_patent_data/page_212.jpg
# Saved ../../data/patent_data/interim_patent_data/page_213.jpg
# Saved ../../data/patent_data/interim_patent_data/page_214.jpg
# Saved ../../data/patent_data/interim_patent_data/page_215.jpg
# Saved ../../data/patent_data/interim_patent_data/page_216.jpg
# Saved ../../data/patent_data/interim_patent_data/page_217.jpg
# Saved ../../data/patent_data/interim_patent_data/page_218.jpg
# Saved ../../data/patent_data/interim_patent_data/page_219.jpg
# Saved ../../data/patent_data/interim_patent_data/page_220.jpg
# Saved ../../data/patent_data/interim_patent_data/page_221.jpg
# Saved ../../data/patent_data/interim_patent_data/page_222.jpg
# Saved ../../data/patent_data/interim_patent_data/page_223.jpg
# Saved ../../data/patent_data/interim_patent_data/page_224.jpg
# Saved ../../data/patent_data/interim_patent_data/page_225.jpg
# Saved ../../data/patent_data/interim_patent_data/page_226.jpg
# Saved ../../data/patent_data/interim_patent_data/page_227.jpg

# %%
# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "../../data/patent_data/interim_patent_data/page_1.jpg"

# Getting the base64 string
base64_image = encode_image(image_path)

headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}

payload = {
  "model": "gpt-4o",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": prompt
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 3000
}

# %%
# Query GPT
response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

print(response.json())
# Out:
# {'id': 'chatcmpl-AAwUzkt3XMLfUgpkkgpeVmSTNQo3E', 'object': 'chat.completion', 'created': 1727171513, 'model': 'gpt-4o-2024-05-13', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'PrivRegNr\tName1\tName2\tVorname1\tName3\tVorname2\tName4\tVorname3\tTitel\tSchlagworte\tOrt\tJahr\tEingereichtam\n1\tSteller\t\tAnton\t\t\tMeine Verfahrenart auf alles Getreide-Größtnen durch günstigsten zur anderen Substanten ordnige und die edelsten Papieze zu verfertigen, wie hier dieses Blut und jenes Wasser der Kürperleib ist...\tStrohpapier\tWien\t1816\t18.06.1816\n2\tOberhaimer\t\tAnton\t\t\tDas Gebirker oder Felsenheimerische Lack-Lake (roter Indigo) als Cochenille Ersatz und Mittel zur Scharlachzeugung\tCochenille, Schachille, Lack-Lake, Indigo\tWien\t1816\t10.06.1816\n3\tRupprecht\t\tJoseph\t\t\tBadeaparat mit Brennstoffeinsparung\tBadeofen\tWien\t1821\t02.07.1821\n4\tVogtländer\tJohan\tFriedrich\t\t\tBeschreibung der periskopischen Gliser und charakteristischen Kenneichen derselben\tPeriskopische Gläser, Brille\tWien\t1816\t09.09.1816\n5\tStrauss\t\tAnton\t\t\tErfindung einer Druckmaschine\tDruckmaschine\tWien\t1815\t02.12.1815\n6\tKoehler\tA.C.\tftv.v.\t\t\tErfindung, ... daß man vermittel einer Maschine an den Stand gesetzt wird, die Güte der Schwälsfeuermostern, in Beziehung auf die Stärke des Haares, genau und unrichtig zu messen\tWollmesser\tZnaim/Znákuža\tWien\t1823\t18.06.1823\n7\tSchafzahl\tFranz\tXaver\t\t\tBeschreibung der Maschinen Nagel-Moden in 1/4 MaßStabe\tNagel\tGraz\t1816\t18.04.1816\n8\tMayer\t\tBlasius\t\t\tBeschreibung der Unterziehereifen – verliehene Privife über seine Nagelzeugverwaltungsmachine\tNagel\tWien\t1818\t21.05.1818\n9\tLeppich\t\tCaspar\t\t\tBeschreibung meiner neu erfundenen Nagel-Erzeugungs-Maschine\tNagel\tWien\t1818\t15.10.1818\n10\tBischoff\t\tThomas\t\t\tBeschreibung der erfundenden Maschine "Mühlstühl", auf welcher nicht nur ... Seidenbänder, sondern alle Gattungen Zeugz, durch eine sitzende Person gewoben werden können\tBandstühl\tWien\t1816\t20.09.1816\n11\tMailat\t\tAnna\t\t\tEine Erzeugung von Weinflasches, statt mit Leinwand mit Holz\tWeinfläsching, Weinfaß\tZnaim/Wien\t1821\t04.09.1821\n12\tRussewurm\t\tAugustin\t\t\tBeschreibung eines Malz-, Flachs-, Obst- etc. Dörfofels\tDürrefasselier\tWien\t1823\t27.05.1823\n13\tKissling\t\tJohanna\t\t\tBeschreibung einer ... Entdeckung, welche ... darin bestehet, Hufe als geöffneter Seide, welche die florenstreichen Hüte in Schönheit und Dauer betreffend, und ohne die Schönheit des Gelechtes zu schäden, gespart werden können\tFlörenstreichen Hüte, Blondegewebe, Flachse\tWien\t1821\t01.10.1821\n14\tPundhneiller\t\tJosef\t\t\tBeschreibung der Gedrukten zudchke vom Seidepeigeflawerks\tBlechteige Schweideiwerkt\tWien\t1821\t09.11.1821\n15\tTedeschi\t\tAnton\t\t\tBeschreibung einer durchdaken Lederleinlade in Papple/Pappen-deckel) und Lederateiges Papier, per Super(naingdie) Lederbandle\tBepapke, Papier, Lederbändlein\tWien\t1821\t03.09.1821\n16\tKınzel\tA.\tChristoph\t\t\tBeschreibung des Modelle Intervallumt mit seinen sechs Mutationen Mobile Intervallum, Getriebe\tPrag\t1821\t06.05.1821\n17\tEhrenfeld\tThaddaeus\t\tSeski\tJulius\t\tBeschreibung der neu erfundenen Getreide-Satmaschine\tSatmaschine\tWien\t1821\t11.10.1821\n18\tKlein\t\tIgnaz\t\t\tDie Bestandung der revidierten Finger- und Turnmaier-Putzfaste\tSeife, Fleckputzmittel\tInnsbruck\t1821\t24.09.1821\n19\tTumfort\t\tFranz\t\t\tBeschreibung des ja verworfenaln Gängers, ... und engen zu verfressenem Müllstühl, welcher Fütchel... jedoch auf einer nöwen kenn Baue ferkenen\tMühlstühl, Ladhebenmaschinen, Sendelband\tWien\t1821\t08.12.1821\n20\tWaldhoer\t\tKarl\t\t\t... neuen Erfındung, ... dass zu bestehen, ... eindeutig mit neuen erfundenen Ladhebemaschine, in Verbindung mit der Stellgälde und Seidenhandschuhbotachke aller Dienstag Moden-Schide-Massk bieten\nBandstühl, Ladhebenmaschinen, Seidenband\tWien\t1822\t\n21\tFelix\t\tGregor\t\t\t... Erfindung, daß die ...

# %%
raw_string = response.json()['choices'][0]['message']['content']

# %%
pd.read_csv(StringIO(raw_string), delimiter="\t").head(5)
# Out:
#   PrivRegNr        Name1  Name2   Vorname1 Name3 Vorname2  \
# 0         1      Steller    NaN      Anton   NaN      NaN
# 1         2   Oberhaimer    NaN      Anton   NaN      NaN
# 2         3    Rupprecht    NaN     Joseph   NaN      NaN
# 3         4  Vogtländer  Johan  Friedrich   NaN      NaN
# 4         5      Strauss    NaN      Anton   NaN      NaN
#
#                                                Name4  \
# 0  Meine Verfahrenart auf alles Getreide-Größtne...
# 1  Das Gebirker oder Felsenheimerische Lack-Lake ...
# 2                Badeaparat mit Brennstoffeinsparung
# 3  Beschreibung der periskopischen Gliser und cha...
# 4                      Erfindung einer Druckmaschine
#
#                                     Vorname3 Titel Schlagworte         Ort  \
# 0                                Strohpapier  Wien        1816  18.06.1816
# 1  Cochenille, Schachille, Lack-Lake, Indigo  Wien        1816  10.06.1816
# 2                                   Badeofen  Wien        1821  02.07.1821
# 3               Periskopische Gläser, Brille  Wien        1816  09.09.1816
# 4                              Druckmaschine  Wien        1815  02.12.1815
#
#   Jahr  Eingereichtam
# 0  NaN            NaN
# 1  NaN            NaN
# 2  NaN            NaN
# 3  NaN            NaN
# 4  NaN            NaN
